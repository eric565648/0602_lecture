# %% [markdown]
# ## 04-03. Face Detect

# %% [markdown]
# ### Basic Practice
#
# ### In this section we are going to try out the face detect function.
#
# <img style="float: left;"  src="images/Result.png"  width="60%">

# %%
#Remember to import these head file

import numpy  as  np
import scipy  as  sp
import cv2
import time
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (10, 10)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels

# %% [markdown]
# #### 1. Finding The Face

# %%
# This is the code in Tutorial show you how to use this function

img = cv2.imread('images/face.jpg')
vis = cv2.imread('images/face.jpg')

faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# %time faces = faceCascade.detectMultiScale(gray, scaleFactor=2, minNeighbors=5, minSize=(10, 10), flags = 4)

# Visualization
dst = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
dst1 = cv2.cvtColor(vis, cv2.COLOR_BGR2RGB)
for (x, y, w, h) in faces:
    cv2.rectangle(dst1, (x, y), (x+w, y+h), (0, 255, 0), 5)


plt.subplot(121),plt.imshow(dst, cmap = 'brg')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst1, cmap = 'brg')
plt.title("Found {0} faces!".format(len(faces))), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# CPU times: user 39.8 ms, sys: 10.8 ms, total: 50.6 ms
# Wall time: 54.4 ms

# %%
# Now, trying to apply it on the other picture "street1.jpg" and "street2.jpg"

img1 = cv2.imread('images/street1.jpg')
img1 = cv2.resize( img1 , (800 , 600) ,interpolation=cv2.INTER_NEAREST)

img2 = cv2.imread('images/street2.jpg')
img2 = cv2.resize( img2 , (800 , 600) ,interpolation=cv2.INTER_NEAREST)
    

####### Finish your code down here ######





#########################################
# Out:
# CPU times: user 77.6 ms, sys: 5.93 ms, total: 83.5 ms
# Wall time: 12.9 ms
# CPU times: user 10.2 ms, sys: 11.8 ms, total: 22 ms
# Wall time: 4.47 ms

# %% [markdown]
# #### 2. Apply Into Usage

# %%
# For example, we can use the size of the face to detect
# the relative distant between people and our car.

# Now, try to write a code to determine 
# which woman in "street1.jpg" and "street2.jpg" is closer to us.

# Hint: What are the meaning of (x, y, w, h) in faces?


####### Finish your code down here ######





#########################################

# %% [markdown]
# ### Bouns Practice

# %% [markdown]
# #### 1. Finding The FaceS

# %%
# This is how we can detect more than one face in picture.

img = cv2.imread('images/group_1.jpg')
vis = cv2.imread('images/group_1.jpg')

faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# %time faces = faceCascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5, minSize=(10, 10), flags = 2)

# Visualization
dst = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
dst1 = cv2.cvtColor(vis, cv2.COLOR_BGR2RGB)
for (x, y, w, h) in faces:
    cv2.rectangle(dst1, (x, y), (x+w, y+h), (0, 255, 0), 5)


plt.subplot(121),plt.imshow(dst, cmap = 'brg')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst1, cmap = 'brg')
plt.title("Found {0} faces!".format(len(faces))), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# CPU times: user 55.1 ms, sys: 0 ns, total: 55.1 ms
# Wall time: 11.3 ms

# %%
# You may notice that sometimes it will fail to find out the faces in picture
# or tell you there is a face in a empty place.

# Now, trying to apply it on the other picture "street1.jpg" and "street2.jpg"
# and answer how many wrong cases appear.

img2 = cv2.imread('images/group_3.jpg')
dst2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

####### Finish your code down here ######



#########################################
# Out:
# CPU times: user 27.9 ms, sys: 0 ns, total: 27.9 ms
# Wall time: 5.84 ms
# CPU times: user 3.75 s, sys: 57.8 ms, total: 3.81 s
# Wall time: 574 ms

# %% [markdown]
# #### 2. Modify The Parameter

# %%
# Can you find more faces in the previous block?

# Hint: 
#       There are many parameters in "detectMultiScale".
#       Why don't you try it out?
